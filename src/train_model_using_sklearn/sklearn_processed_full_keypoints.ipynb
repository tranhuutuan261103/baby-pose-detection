# %%
# Thêm autoreload vào để tự động reload lại module nếu có thay đổi code trong module
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler

# Các model scikit learn cho bài toán phân loại
from sklearn.svm import SVC # Support vector machine
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score, cross_val_predict, KFold
from sklearn.metrics import confusion_matrix, accuracy_score
from xgboost import XGBClassifier
import json
from sklearn.model_selection import RandomizedSearchCV

import warnings
warnings.filterwarnings("ignore")

import os, sys
sys.path.append(os.path.abspath(".."))

from utils.training_storage_helper import save_params, save_model
from utils.progress_wrapper import ProgressWrapper

seed = 42
np.random.seed(seed)

# %% [markdown]
# ### Setup params

# %%
hyper_parameters_path = "../hyper_parameters_full_keypoints"
model_path = "../best_models_full_keypoints"

# %% [markdown]
# # 1. Prepare data

# %%
train_df = pd.read_csv("../../data/data_full_keypoints_processed.csv")

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 100 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   label               421 non-null    object
#  1   nose_x              421 non-null    float64
#  2   nose_y              421 non-null    float64
#  3   nose_z              421 non-null    float64
#  4   left_eye_inner_x    421 non-null    float64
#  5   left_eye_inner_y    421 non-null    float64
#  6   left_eye_inner_z    421 non-null    float64
#  7   left_eye_x          421 non-null    float64
#  8   left_eye_y          421 non-null    float64
#  9   left_eye_z          421 non-null    float64
#  10  left_eye_outer_x    421 non-null    float64
#  11  left_eye_outer_y    421 non-null    float64
#  12  left_eye_outer_z    421 non-null    float64
#  13  right_eye_inner_x   421 non-null    float64
#  14  right_eye_inner_y   421 non-null    float64
#  15  right_eye_inner_z   421 non-null    float64
#  16  right_eye_x         421 non-null    float64
#  17  right_eye_y         421 non-null    float64
#  18  right_eye_z         421 non-null    float64
#  19  right_eye_outer_x   421 non-null    float64
#  20  right_eye_outer_y   421 non-null    float64
#  21  right_eye_outer_z   421 non-null    float64
#  22  left_ear_x          421 non-null    float64
#  23  left_ear_y          421 non-null    float64
#  24  left_ear_z          421 non-null    float64
#  25  right_ear_x         421 non-null    float64
#  26  right_ear_y         421 non-null    float64
#  27  right_ear_z         421 non-null    float64
#  28  mouth_left_x        421 non-null    float64
#  29  mouth_left_y        421 non-null    float64
#  30  mouth_left_z        421 non-null    float64
#  31  mouth_right_x       421 non-null    float64
#  32  mouth_right_y       421 non-null    float64
#  33  mouth_right_z       421 non-null    float64
#  34  left_shoulder_x     421 non-null    float64
#  35  left_shoulder_y     421 non-null    float64
#  36  left_shoulder_z     421 non-null    float64
#  37  right_shoulder_x    421 non-null    float64
#  38  right_shoulder_y    421 non-null    float64
#  39  right_shoulder_z    421 non-null    float64
#  40  left_elbow_x        421 non-null    float64
#  41  left_elbow_y        421 non-null    float64
#  42  left_elbow_z        421 non-null    float64
#  43  right_elbow_x       421 non-null    float64
#  44  right_elbow_y       421 non-null    float64
#  45  right_elbow_z       421 non-null    float64
#  46  left_wrist_x        421 non-null    float64
#  47  left_wrist_y        421 non-null    float64
#  48  left_wrist_z        421 non-null    float64
#  49  right_wrist_x       421 non-null    float64
#  50  right_wrist_y       421 non-null    float64
#  51  right_wrist_z       421 non-null    float64
#  52  left_pinky_x        421 non-null    float64
#  53  left_pinky_y        421 non-null    float64
#  54  left_pinky_z        421 non-null    float64
#  55  right_pinky_x       421 non-null    float64
#  56  right_pinky_y       421 non-null    float64
#  57  right_pinky_z       421 non-null    float64
#  58  left_index_x        421 non-null    float64
#  59  left_index_y        421 non-null    float64
#  60  left_index_z        421 non-null    float64
#  61  right_index_x       421 non-null    float64
#  62  right_index_y       421 non-null    float64
#  63  right_index_z       421 non-null    float64
#  64  left_thumb_x        421 non-null    float64
#  65  left_thumb_y        421 non-null    float64
#  66  left_thumb_z        421 non-null    float64
#  67  right_thumb_x       421 non-null    float64
#  68  right_thumb_y       421 non-null    float64
#  69  right_thumb_z       421 non-null    float64
#  70  left_hip_x          421 non-null    float64
#  71  left_hip_y          421 non-null    float64
#  72  left_hip_z          421 non-null    float64
#  73  right_hip_x         421 non-null    float64
#  74  right_hip_y         421 non-null    float64
#  75  right_hip_z         421 non-null    float64
#  76  left_knee_x         421 non-null    float64
#  77  left_knee_y         421 non-null    float64
#  78  left_knee_z         421 non-null    float64
#  79  right_knee_x        421 non-null    float64
#  80  right_knee_y        421 non-null    float64
#  81  right_knee_z        421 non-null    float64
#  82  left_ankle_x        421 non-null    float64
#  83  left_ankle_y        421 non-null    float64
#  84  left_ankle_z        421 non-null    float64
#  85  right_ankle_x       421 non-null    float64
#  86  right_ankle_y       421 non-null    float64
#  87  right_ankle_z       421 non-null    float64
#  88  left_heel_x         421 non-null    float64
#  89  left_heel_y         421 non-null    float64
#  90  left_heel_z         421 non-null    float64
#  91  right_heel_x        421 non-null    float64
#  92  right_heel_y        421 non-null    float64
#  93  right_heel_z        421 non-null    float64
#  94  left_foot_index_x   421 non-null    float64
#  95  left_foot_index_y   421 non-null    float64
#  96  left_foot_index_z   421 non-null    float64
#  97  right_foot_index_x  421 non-null    float64
#  98  right_foot_index_y  421 non-null    float64
#  99  right_foot_index_z  421 non-null    float64
# dtypes: float64(99), object(1)
# memory usage: 329.0+ KB

# %%
train_df.columns
# Out:
# Index(['label', 'nose_x', 'nose_y', 'nose_z', 'left_eye_inner_x',
#        'left_eye_inner_y', 'left_eye_inner_z', 'left_eye_x', 'left_eye_y',
#        'left_eye_z', 'left_eye_outer_x', 'left_eye_outer_y',
#        'left_eye_outer_z', 'right_eye_inner_x', 'right_eye_inner_y',
#        'right_eye_inner_z', 'right_eye_x', 'right_eye_y', 'right_eye_z',
#        'right_eye_outer_x', 'right_eye_outer_y', 'right_eye_outer_z',
#        'left_ear_x', 'left_ear_y', 'left_ear_z', 'right_ear_x', 'right_ear_y',
#        'right_ear_z', 'mouth_left_x', 'mouth_left_y', 'mouth_left_z',
#        'mouth_right_x', 'mouth_right_y', 'mouth_right_z', 'left_shoulder_x',
#        'left_shoulder_y', 'left_shoulder_z', 'right_shoulder_x',
#        'right_shoulder_y', 'right_shoulder_z', 'left_elbow_x', 'left_elbow_y',
#        'left_elbow_z', 'right_elbow_x', 'right_elbow_y', 'right_elbow_z',
#        'left_wrist_x', 'left_wrist_y', 'left_wrist_z', 'right_wrist_x',
#        'right_wrist_y', 'right_wrist_z', 'left_pinky_x', 'left_pinky_y',
#        'left_pinky_z', 'right_pinky_x', 'right_pinky_y', 'right_pinky_z',
#        'left_index_x', 'left_index_y', 'left_index_z', 'right_index_x',
#        'right_index_y', 'right_index_z', 'left_thumb_x', 'left_thumb_y',
#        'left_thumb_z', 'right_thumb_x', 'right_thumb_y', 'right_thumb_z',
#        'left_hip_x', 'left_hip_y', 'left_hip_z', 'right_hip_x', 'right_hip_y',
#        'right_hip_z', 'left_knee_x', 'left_knee_y', 'left_knee_z',
#        'right_knee_x', 'right_knee_y', 'right_knee_z', 'left_ankle_x',
#        'left_ankle_y', 'left_ankle_z', 'right_ankle_x', 'right_ankle_y',
#        'right_ankle_z', 'left_heel_x', 'left_heel_y', 'left_heel_z',
#        'right_heel_x', 'right_heel_y', 'right_heel_z', 'left_foot_index_x',
#        'left_foot_index_y', 'left_foot_index_z', 'right_foot_index_x',
#        'right_foot_index_y', 'right_foot_index_z'],
#       dtype='object')

# %%
train_df.head()
# Out:
#       label    nose_x    nose_y    nose_z  left_eye_inner_x  left_eye_inner_y  \
# 0  1_lie_on  0.043735 -0.438350 -0.262433          0.044239         -0.481605
# 1  1_lie_on -0.012077 -0.438393 -0.340744          0.022831         -0.478344
# 2  1_lie_on  0.012135 -0.373490 -0.618891          0.056198         -0.426572
# 3  1_lie_on  0.094005 -0.439339 -0.151025          0.089825         -0.483317
# 4  1_lie_on -0.029846 -0.490374 -0.204487          0.016633         -0.490335
#
#    left_eye_inner_z  left_eye_x  left_eye_y  left_eye_z  ...  left_heel_z  \
# 0         -0.241004    0.058783   -0.483684   -0.240937  ...    -0.056336
# 1         -0.317016    0.042567   -0.473720   -0.316981  ...     0.079769
# 2         -0.598566    0.083506   -0.427920   -0.598480  ...     0.363640
# 3         -0.116603    0.103984   -0.485039   -0.116664  ...    -0.185648
# 4         -0.167069    0.045671   -0.475213   -0.166802  ...    -0.016234
#
#    right_heel_x  right_heel_y  right_heel_z  left_foot_index_x  \
# 0     -0.143124      0.817404     -0.073264          -0.094777
# 1     -0.087830      0.761904      0.049899           0.051305
# 2      0.075779      0.883344      0.161039           0.231620
# 3     -0.093709      0.766372     -0.233900          -0.054249
# 4      0.007369      0.638521     -0.098527           0.273508
#
#    left_foot_index_y  left_foot_index_z  right_foot_index_x  \
# 0           0.961264          -0.166788           -0.178679
# 1           0.810328          -0.046716           -0.160051
# 2           0.713266           0.287587            0.089882
# 3           0.855183          -0.285776           -0.090941
# 4           0.729336          -0.119508            0.002807
#
#    right_foot_index_y  right_foot_index_z
# 0            1.027750           -0.190334
# 1            0.880444           -0.097076
# 2            1.046537            0.005253
# 3            0.831457           -0.380920
# 4            0.799412           -0.203064
#
# [5 rows x 100 columns]

# %%
sns.countplot(x="label", data=train_df)
# Out:
# <Axes: xlabel='label', ylabel='count'>

# %% [markdown]
# # 2. Pre-training

# %%
# Chuyển dữ liệu của label về dạng số
from sklearn.preprocessing import LabelEncoder

# Khởi tạo LabelEncoder
label_encoder = LabelEncoder()
train_df["label"] = label_encoder.fit_transform(train_df["label"])

# %%
# Extract features
X_train = train_df.drop(columns="label")
y_train = train_df["label"]

# %%
X_train.head()
# Out:
#      nose_x    nose_y    nose_z  left_eye_inner_x  left_eye_inner_y  \
# 0  0.043735 -0.438350 -0.262433          0.044239         -0.481605
# 1 -0.012077 -0.438393 -0.340744          0.022831         -0.478344
# 2  0.012135 -0.373490 -0.618891          0.056198         -0.426572
# 3  0.094005 -0.439339 -0.151025          0.089825         -0.483317
# 4 -0.029846 -0.490374 -0.204487          0.016633         -0.490335
#
#    left_eye_inner_z  left_eye_x  left_eye_y  left_eye_z  left_eye_outer_x  \
# 0         -0.241004    0.058783   -0.483684   -0.240937          0.073646
# 1         -0.317016    0.042567   -0.473720   -0.316981          0.060247
# 2         -0.598566    0.083506   -0.427920   -0.598480          0.108771
# 3         -0.116603    0.103984   -0.485039   -0.116664          0.117586
# 4         -0.167069    0.045671   -0.475213   -0.166802          0.068868
#
#    ...  left_heel_z  right_heel_x  right_heel_y  right_heel_z  \
# 0  ...    -0.056336     -0.143124      0.817404     -0.073264
# 1  ...     0.079769     -0.087830      0.761904      0.049899
# 2  ...     0.363640      0.075779      0.883344      0.161039
# 3  ...    -0.185648     -0.093709      0.766372     -0.233900
# 4  ...    -0.016234      0.007369      0.638521     -0.098527
#
#    left_foot_index_x  left_foot_index_y  left_foot_index_z  \
# 0          -0.094777           0.961264          -0.166788
# 1           0.051305           0.810328          -0.046716
# 2           0.231620           0.713266           0.287587
# 3          -0.054249           0.855183          -0.285776
# 4           0.273508           0.729336          -0.119508
#
#    right_foot_index_x  right_foot_index_y  right_foot_index_z
# 0           -0.178679            1.027750           -0.190334
# 1           -0.160051            0.880444           -0.097076
# 2            0.089882            1.046537            0.005253
# 3           -0.090941            0.831457           -0.380920
# 4            0.002807            0.799412           -0.203064
#
# [5 rows x 99 columns]

# %%
y_train
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 416    2
# 417    2
# 418    2
# 419    2
# 420    2
# Name: label, Length: 421, dtype: int32

# %%
# Chuẩn hoá dữ liệu trên tập huấn luyện bằng z-scores
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)

# %%
# X lúc này là một DataFrame mới với các cột mới được đánh số từ 0 đến n-1, trong đó n là số lượng cột trong dữ liệu ban đầu
X_train
# Out:
# array([[ 0.52775415, -0.42049679, -0.29382119, ..., -0.55930841,
#          1.88001845, -0.67341789],
#        [-0.0558041 , -0.42160751, -0.63397871, ..., -0.49781773,
#          1.12529974, -0.46827462],
#        [ 0.19735504,  1.26606068, -1.84216738, ...,  0.32723686,
#          1.97626942, -0.24317618],
#        ...,
#        [ 0.00592068, -0.4051071 , -0.34971118, ...,  0.17085354,
#          0.40486211,  0.31718887],
#        [ 0.14065468,  0.1898863 ,  1.60055882, ...,  0.14144492,
#         -0.23519593, -0.09189938],
#        [-0.08153171, -0.71228088,  1.88580145, ...,  0.05538345,
#          0.70851491, -0.60748757]])

# %% [markdown]
# # 3. Training

# %%
k_fold = KFold(n_splits=5, random_state=seed, shuffle=True)

# %%
def evaluate_model(name, model, results):
    # Đánh giá Model
    accuracy = cross_val_score(
        model, X_train, y_train, cv=k_fold, scoring="accuracy", n_jobs=-1, verbose=1
    ).mean()

    f1_score = cross_val_score(model, X_train, y_train, cv=k_fold, scoring="f1_macro").mean()
    results.append((name, accuracy, f1_score))

# %%
algorithms = [
    ("LR", LogisticRegression(random_state=seed)),
    ("SVC", SVC(probability=True, random_state=seed)),
    ("KNN", KNeighborsClassifier()),
    ("DTC", DecisionTreeClassifier(random_state=seed)),
    ("RF", RandomForestClassifier(random_state=seed)),
    ("XGB", XGBClassifier(random_state=seed)),
]

models = {}
results_before_tunning = []

for name, model in algorithms:
    trained_model = model.fit(X_train, y_train)
    models[name] = trained_model
    evaluate_model(name, model, results_before_tunning)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.7s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.9s finished

# %%
def print_results(results):
    results.sort(key=lambda el: el[2], reverse=True)

    return pd.DataFrame(
        results,
        columns=[
            "Model",
            "Accuracy score",
            "F1 score",
        ],
    )

print_results(results_before_tunning)
# Out:
#   Model  Accuracy score  F1 score
# 0    RF        0.964342  0.965935
# 1   XGB        0.950084  0.952165
# 2   SVC        0.950084  0.950182
# 3    LR        0.945350  0.945976
# 4   DTC        0.933473  0.937137
# 5   KNN        0.924006  0.923681

# %%
sns.barplot(x="F1 score", y="Model", data=print_results(results_before_tunning))
# Out:
# <Axes: xlabel='F1 score', ylabel='Model'>

# %% [markdown]
# # 4. Evaluate

# %%
y_pred = models['RF'].predict(X_train)
cm_full_train = confusion_matrix(y_train, y_pred)
accuracy = accuracy_score(y_train, y_pred)
cm_full_train, accuracy
# Out:
# (array([[153,   1,   0],
#         [  1, 146,   0],
#         [  0,   0, 120]], dtype=int64),
#  0.995249406175772)

# %%
svc_best_model = RandomForestClassifier(random_state=seed)

svc_best_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
accuracy = cross_val_score(svc_best_model, X_train, y_train, cv=k_fold, scoring="accuracy").mean()
y_pred = cross_val_predict(svc_best_model, X_train, y_train, cv=k_fold)
cm_cross_val = confusion_matrix(y_train, y_pred)
accuracy, cm_cross_val
# Out:
# (0.9643417366946778,
#  array([[149,   5,   0],
#         [  8, 139,   0],
#         [  0,   2, 118]], dtype=int64))

# %%
label_counts = np.sum(cm_cross_val, axis=1)
cm_cross_val = cm_cross_val / label_counts[:, None]
confusion_matrix_df = pd.DataFrame(cm_cross_val, index=["Ngửa", "Nghiêng", "Sấp"], columns=["Ngửa", "Nghiêng", "Sấp"])

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(confusion_matrix_df, linewidths=1, annot=True, ax=ax, fmt="g", cmap="crest")
# Out:
# <Axes: >

# %% [markdown]
# # 5. Find best model

# %%
results_after_tuning = []

# %%
random_forest = models["RF"]

# Định nghĩa phạm vi của các siêu tham số cần tối ưu
param_grid = {
    'n_estimators': [50, 100, 200, 300, 400, 500],
    'max_features': ['log2', 'sqrt'],
    'max_depth': [10, 20, 30, 40, 50, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'bootstrap': [True, False]
}

# Tạo RandomizedSearchCV
random_search = RandomizedSearchCV(estimator = random_forest, param_distributions = param_grid,
                                n_iter = 100, cv = k_fold, verbose=3, random_state=seed, n_jobs = -1)

# Tiến hành tìm kiếm siêu tham số
random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=RandomForestClassifier(random_state=42),
#                    n_iter=100, n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [10, 20, 30, 40, 50, None],
#                                         'max_features': ['log2', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [50, 100, 200, 300, 400,
#                                                          500]},
#                    random_state=42, verbose=3)

# %%
random_search.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 2,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 10,
#  'bootstrap': True}

# %%
save_params(random_search.best_params_, f"./{hyper_parameters_path}/random_forest.json")

# %%
with open(f'./{hyper_parameters_path}/random_forest.json', 'r') as f:
    best_params = json.load(f)
    best_params["bootstrap"] = bool(best_params["bootstrap"])

# Khởi tạo một mô hình Random Forest mới với các tham số tối ưu
best_random_forest_model = RandomForestClassifier(**best_params, random_state=seed, verbose=1)
best_random_forest_model.fit(X_train, y_train)

# Huấn luyện mô hình mới với dữ liệu huấn luyện của bạn
result = []
evaluate_model("RF", best_random_forest_model, result)
results_after_tuning.append(result[0])
print_results(result)
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    1.8s finished
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
#   Model  Accuracy score  F1 score
# 0    RF        0.969104  0.970305

# %%
accuracy_rf_best = cross_val_score(best_random_forest_model, X_train, y_train, cv=k_fold, scoring="accuracy").mean()
y_pred_rf_best = cross_val_predict(best_random_forest_model, X_train, y_train, cv=k_fold)
cm_cross_val_rf_best = confusion_matrix(y_train, y_pred_rf_best)
accuracy_rf_best, cm_cross_val_rf_best
# Out:
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=1)]: Done 199 tasks      | elapsed:    0.0s
# (0.9691036414565826,
#  array([[149,   5,   0],
#         [  6, 141,   0],
#         [  0,   2, 118]], dtype=int64))

# %%
label_counts = np.sum(cm_cross_val_rf_best, axis=1)
cm_cross_val = cm_cross_val_rf_best / label_counts[:, None]
confusion_matrix_df = pd.DataFrame(cm_cross_val, index=["Ngửa", "Nghiêng", "Sấp"], columns=["Ngửa", "Nghiêng", "Sấp"])

fig, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(confusion_matrix_df, linewidths=1, annot=True, ax=ax, fmt="g", cmap="crest")
# Out:
# <Axes: >

# %%
save_model(scaler, f"{model_path}/input_scaler.pkl")
save_model(best_random_forest_model, f"{model_path}/random_forest.pkl")

# %%
from sklearn.model_selection import GridSearchCV

svc_model = models["SVC"]

param_grid = {
    "decision_function_shape": ["ovo", "ovr", "ovo", "ovr"],
    "gamma": ["scale", "auto", "scale", "auto"],
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
}

# Tạo GridSearchCV instance
svc_best_model = GridSearchCV(svc_model, param_grid, cv=5, verbose=3, n_jobs=-1)

# Tiến hành tinh chỉnh siêu tham số trên mô hình đã huấn luyện
svc_best_model.fit(X_train, y_train)

# In ra các siêu tham số tốt nhất được tìm thấy
print("Best Parameters:", svc_best_model.best_params_)
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# Best Parameters: {'decision_function_shape': 'ovo', 'gamma': 'scale', 'kernel': 'rbf'}

# %%
json.dump(svc_best_model.best_params_, open(f"{hyper_parameters_path}/SVC.json", "w"))

# %%
best_params = json.load(open(f"{hyper_parameters_path}/SVC.json", "r"))
svc_best_model = SVC(**best_params, random_state=seed)
svc_best_model.fit(X_train, y_train)
# Out:
# SVC(decision_function_shape='ovo', random_state=42)

# %%
result = []
evaluate_model("SVC", svc_best_model, result)
print_results(result)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.0s finished
#   Model  Accuracy score  F1 score
# 0   SVC        0.950084  0.950182

# %%
save_model(svc_best_model, f"{model_path}/svc.pkl")
